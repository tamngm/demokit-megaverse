# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\minhtam.nguyen\0_Data_project\demokit-megaverse\data\usage_final\fact_final_sales_product_adjusted.csv", delimiter=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   terms                  746 non-null    object
#  1   section                746 non-null    object
#  2   season                 746 non-null    object
#  3   material               746 non-null    object
#  4   sales_no               700 non-null    float64
#  5   sales_yes              701 non-null    float64
#  6   volume_no              700 non-null    float64
#  7   volume_yes             701 non-null    float64
#  8   recommendation         746 non-null    object
#  9   price_no               700 non-null    float64
#  10  price_yes              701 non-null    float64
#  11  baseline_price_no      700 non-null    float64
#  12  baseline_price_yes     701 non-null    float64
#  13  discount_rec           746 non-null    object
# ...

# %%
# Load your data
df

# Map Pandas types to standard AWS data types
type_mapping = {
    'int64': 'int',
    'float64': 'double',
    'bool': 'boolean',
    'object': 'string',
    'datetime64[ns]': 'timestamp'
}

# Generate the comma-separated string
bulk_string = ", ".join([f"{col} {type_mapping.get(str(dtype), 'string')}" for col, dtype in df.dtypes.items()])
print(bulk_string)
# Out:
# terms string, section string, season string, material string, sales_no double, sales_yes double, volume_no double, volume_yes double, recommendation string, price_no double, price_yes double, baseline_price_no double, baseline_price_yes double, discount_rec string, current_position string, discount_bucket_label string
